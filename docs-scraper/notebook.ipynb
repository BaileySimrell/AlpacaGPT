# %%
import os
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
import html2text
import hashlib
import shutil
import readability
import logging

# Set of visited URLs to prevent infinite recursion
visited_urls = set()

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def download_page(url, timeout=10):
    """
    Downloads the content of a web page from the given URL.

    Args:
        url (str): The URL of the web page to download.
        timeout (int): Timeout duration in seconds.

    Returns:
        str: The content of the web page as a string, or None if there was an error.

    Raises:
        requests.RequestException: If there was an error while downloading the web page.
    """
    try:
        response = requests.get(url, timeout=timeout)
        response.raise_for_status()  # Raises an error for bad status codes
        return response.text
    except requests.RequestException as e:
        logging.warning(f"Error downloading {url}: {e}")
        return None

def extract_urls(html, base_url, ignored_extensions=None):
    """
    Extracts all URLs from the given HTML content, resolving relative URLs and ignoring hash fragments.

    Args:
        html (str): The HTML content to extract URLs from.
        base_url (str): The base URL used to resolve relative URLs.
        ignored_extensions (list): List of file extensions to ignore.

    Returns:
        set: A set of URLs extracted from the HTML content.
    """
    if ignored_extensions is None:
        ignored_extensions = ['.txt', '.pdf', '.docx']
    soup = BeautifulSoup(html, 'html.parser')
    urls = set()
    for link in soup.find_all('a', href=True):
        href = link['href']
        # Resolve relative URLs and filter by hash fragment
        full_url = urljoin(base_url, href.split('#', 1)[0])
        # Ignore URLs ending with specific file extensions
        if any(full_url.endswith(ext) for ext in ignored_extensions):
            continue
        if urlparse(full_url).netloc == urlparse(base_url).netloc:
            urls.add(full_url)
    return urls

def html_to_markdown(html):
    """
    Converts HTML content to Markdown format.

    Parameters:
    html (str): The HTML content to be converted.

    Returns:
    str: The Markdown representation of the HTML content.
    """
    # Using readability to extract the main content
    document = readability.Document(html)
    summary = document.summary()

    converter = html2text.HTML2Text()
    converter.ignore_links = False
    return converter.handle(summary)

def save_markdown(markdown, folder, filename):
    if not os.path.exists(folder):
        os.makedirs(folder)
    filepath = os.path.join(folder, filename)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(markdown)

def generate_filename(url, base_url):
    """
    Generate a filename based on the given URL and base URL.

    Args:
        url (str): The URL from which the filename will be generated.
        base_url (str): The base URL used to remove the common path from the URL.

    Returns:
        str: The generated filename.
    """
    # Parse the URLs
    parsed_url = urlparse(url)
    parsed_base_url = urlparse(base_url)

    # Remove the base URL path to get the unique part of the path
    base_path = parsed_base_url.path.strip('/')
    unique_path = parsed_url.path.strip('/')

    # If the base_path is not empty, remove it from the start of unique_path
    if base_path and unique_path.startswith(base_path):
        unique_path = unique_path[len(base_path):].strip('/')

    # Split the path into segments and join them with hyphens
    if unique_path:
        filename = unique_path.replace('/', '-').lower() + ".md"
    else:
        filename = "index.md"
    return filename

def scrape_site(url, base_url, base_folder='', depth_limit=3, current_depth=0):
    """
    Scrapes a website recursively, saving the content as markdown files.

    Args:
        url (str): The URL of the website to scrape.
        base_url (str): The base URL of the website.
        base_folder (str, optional): The base folder to save the markdown files. Defaults to ''.
        depth_limit (int, optional): Maximum recursion depth. Defaults to 3.
        current_depth (int, optional): Current recursion depth. Defaults to 0.

    Returns:
        None
    """
    # Ensure the URL starts with the base URL
    if not url.startswith(base_url):
        return

    if url in visited_urls or urlparse(url).netloc != urlparse(base_url).netloc:
        return
    visited_urls.add(url)

    logging.info(f"Scraping {url} (depth: {current_depth})")
    html = download_page(url)
    if html:
        markdown = html_to_markdown(html)
        filename = generate_filename(url, base_url)
        folder = os.path.join(base_folder, urlparse(base_url).netloc)
        save_markdown(markdown, folder, filename)

        # Recursively scrape the extracted URLs up to the depth limit
        if current_depth < depth_limit:
            for link in extract_urls(html, url):
                scrape_site(link, base_url, base_folder, depth_limit, current_depth + 1)

def clean_directory(folder):
    """
    Deletes all files and folders in the specified directory.

    Args:
        folder (str): The path to the directory to be cleaned.

    Raises:
        OSError: If there is an error while deleting files or folders.
    """
    if os.path.exists(folder):
        for filename in os.listdir(folder):
            file_path = os.path.join(folder, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                logging.error(f'Failed to delete {file_path}. Reason: {e}')

# Example usage
base_url = 'https://docs.alpaca.markets/'  # Change this URL to your target
start_url = f'{base_url}'  # Change this URL to your target
base_folder = 'output'

clean_directory(base_folder)
scrape_site(start_url, start_url, base_folder, depth_limit=3)
logging.info("Scraping complete.")
# Out:
# 2024-05-09 00:27:42,918 - INFO - Scraping https://docs.alpaca.markets/ (depth: 0)
# 2024-05-09 00:27:43,248 - INFO - Scraping https://docs.alpaca.markets/docs (depth: 1)
# 2024-05-09 00:27:43,588 - INFO - Scraping https://docs.alpaca.markets/docs/account-plans (depth: 2)
# 2024-05-09 00:27:44,633 - INFO - Scraping https://docs.alpaca.markets/docs/account-opening (depth: 3)
# 2024-05-09 00:27:45,127 - INFO - Scraping https://docs.alpaca.markets/docs/working-with-orders (depth: 3)
# 2024-05-09 00:27:45,659 - INFO - Scraping https://docs.alpaca.markets/docs/crypto-orders (depth: 3)
# 2024-05-09 00:27:46,155 - INFO - Scraping https://docs.alpaca.markets/docs/crypto-fees (depth: 3)
# 2024-05-09 00:27:46,707 - INFO - Scraping https://docs.alpaca.markets/docs/real-time-stock-pricing-data (depth: 3)
# 2024-05-09 00:27:47,398 - INFO - Scraping https://docs.alpaca.markets/docs/funding-via-journals (depth: 3)
# 2024-05-09 00:27:47,709 - INFO - Scraping https://docs.alpaca.markets/docs/user-protection (depth: 3)
# 2024-05-09 00:27:48,448 - INFO - Scraping https://docs.alpaca.markets/docs/using-oauth2-and-trading-api (depth: 3)
# 2024-05-09 00:27:48,807 - INFO - Scraping https://docs.alpaca.markets/docs/paper-trading (depth: 3)
# 2024-05-09 00:27:49,082 - INFO - Scraping https://docs.alpaca.markets/docs/market-data-faq (depth: 3)
# 2024-05-09 00:27:49,604 - INFO - Scraping https://docs.alpaca.markets/reference (depth: 3)
# 2024-05-09 00:27:49,920 - INFO - Scraping https://docs.alpaca.markets/docs/getting-started-with-trading-api (depth: 3)
# 2024-05-09 00:27:50,401 - INFO - Scraping https://docs.alpaca.markets/docs/broker-api-faq (depth: 3)
# 2024-05-09 00:27:51,138 - INFO - Scraping https://docs.alpaca.markets/docs/use-cases (depth: 3)
# 2024-05-09 00:28:32,474 - INFO - Scraping https://docs.alpaca.markets/docs/brokerapi-trading (depth: 3)
# 2024-05-09 00:28:33,000 - INFO - Scraping https://docs.alpaca.markets/docs/non-trade-activities-for-option-events (depth: 3)
# 2024-05-09 00:28:33,609 - INFO - Scraping https://docs.alpaca.markets/docs/accounts-statuses (depth: 3)
# 2024-05-09 00:28:33,820 - INFO - Scraping https://docs.alpaca.markets/edit/getting-started (depth: 2)
# 2024-05-09 00:28:34,326 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:34,365 - INFO - Scraping https://docs.alpaca.markets/edit/non-trade-activities-for-option-events (depth: 3)
# 2024-05-09 00:28:34,836 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:34,852 - INFO - Scraping https://docs.alpaca.markets/edit/options-trading (depth: 3)
# 2024-05-09 00:28:35,349 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:35,366 - INFO - Scraping https://docs.alpaca.markets/edit/sdks-and-tools (depth: 3)
# 2024-05-09 00:28:35,867 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:35,878 - INFO - Scraping https://docs.alpaca.markets/edit/about-broker-api (depth: 3)
# 2024-05-09 00:28:36,313 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:36,330 - INFO - Scraping https://docs.alpaca.markets/edit/working-with-account (depth: 3)
# 2024-05-09 00:28:36,819 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:36,835 - INFO - Scraping https://docs.alpaca.markets/edit/orders-at-alpaca (depth: 3)
# 2024-05-09 00:28:37,609 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:37,626 - INFO - Scraping https://docs.alpaca.markets/edit/alpaca-api-platform (depth: 3)
# 2024-05-09 00:28:38,038 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:38,050 - INFO - Scraping https://docs.alpaca.markets/edit/example-trading-app-ribbit (depth: 3)
# 2024-05-09 00:28:38,614 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:38,628 - INFO - Scraping https://docs.alpaca.markets/edit/crypto-fees (depth: 3)
# 2024-05-09 00:28:39,154 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:39,171 - INFO - Scraping https://docs.alpaca.markets/edit/trading-api (depth: 3)
# 2024-05-09 00:28:39,651 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:39,667 - INFO - Scraping https://docs.alpaca.markets/edit/account-activities (depth: 3)
# 2024-05-09 00:28:40,120 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:40,134 - INFO - Scraping https://docs.alpaca.markets/edit/additional-resources (depth: 3)
# 2024-05-09 00:28:40,811 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:40,827 - INFO - Scraping https://docs.alpaca.markets/edit/local-currency-trading-lct (depth: 3)
# 2024-05-09 00:28:41,255 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:41,271 - INFO - Scraping https://docs.alpaca.markets/edit/brokerapi-trading (depth: 3)
# 2024-05-09 00:28:41,662 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:41,678 - INFO - Scraping https://docs.alpaca.markets/edit/about-alpaca (depth: 3)
# 2024-05-09 00:28:42,118 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:42,131 - INFO - Scraping https://docs.alpaca.markets/edit/funding-via-journals (depth: 3)
# 2024-05-09 00:28:42,619 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:42,635 - INFO - Scraping https://docs.alpaca.markets/edit/paper-trading (depth: 3)
# 2024-05-09 00:28:43,027 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:43,042 - INFO - Scraping https://docs.alpaca.markets/edit/margin-and-short-selling (depth: 3)
# 2024-05-09 00:28:43,445 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:43,457 - INFO - Scraping https://docs.alpaca.markets/edit/options-trading-overview (depth: 3)
# 2024-05-09 00:28:44,148 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:44,162 - INFO - Scraping https://docs.alpaca.markets/edit/streaming-market-data (depth: 3)
# 2024-05-09 00:28:44,604 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:44,621 - INFO - Scraping https://docs.alpaca.markets/edit/crypto-trading (depth: 3)
# 2024-05-09 00:28:45,057 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:45,074 - INFO - Scraping https://docs.alpaca.markets/edit/broker-api-faq (depth: 3)
# 2024-05-09 00:28:45,587 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:45,604 - INFO - Scraping https://docs.alpaca.markets/edit/accounts-statuses (depth: 3)
# 2024-05-09 00:28:45,993 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:46,010 - INFO - Scraping https://docs.alpaca.markets/edit/funding-accounts (depth: 3)
# 2024-05-09 00:28:46,488 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:46,505 - INFO - Scraping https://docs.alpaca.markets/edit/ach-funding (depth: 3)
# 2024-05-09 00:28:46,983 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:46,995 - INFO - Scraping https://docs.alpaca.markets/edit/portfolio-rebalancing (depth: 3)
# 2024-05-09 00:28:47,474 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:47,488 - INFO - Scraping https://docs.alpaca.markets/edit/use-cases (depth: 3)
# 2024-05-09 00:28:47,973 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:47,990 - INFO - Scraping https://docs.alpaca.markets/edit/authentication-1 (depth: 3)
# 2024-05-09 00:28:48,449 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:48,465 - INFO - Scraping https://docs.alpaca.markets/edit/news-api (depth: 3)
# 2024-05-09 00:28:49,087 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:49,102 - INFO - Scraping https://docs.alpaca.markets/edit/user-protection (depth: 3)
# 2024-05-09 00:28:49,583 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:49,599 - INFO - Scraping https://docs.alpaca.markets/login?redirect_uri=/edit/getting-started (depth: 3)
# 2024-05-09 00:28:50,383 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:50,387 - INFO - Scraping https://docs.alpaca.markets/edit/account-opening (depth: 3)
# 2024-05-09 00:28:51,480 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:51,496 - INFO - Scraping https://docs.alpaca.markets/edit/integration-setup-with-alpaca (depth: 3)
# 2024-05-09 00:28:52,189 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:52,205 - INFO - Scraping https://docs.alpaca.markets/edit/websocket-streaming (depth: 3)
# 2024-05-09 00:28:52,619 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:52,635 - INFO - Scraping https://docs.alpaca.markets/edit/about-connect-api (depth: 3)
# 2024-05-09 00:28:53,113 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:53,130 - INFO - Scraping https://docs.alpaca.markets/edit/account-status-events-for-kycaas (depth: 3)
# 2024-05-09 00:28:53,590 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:53,606 - INFO - Scraping https://docs.alpaca.markets/edit/daily-processes-and-reconcilations (depth: 3)
# 2024-05-09 00:28:54,097 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:54,113 - INFO - Scraping https://docs.alpaca.markets/edit/draft-sse-events (depth: 3)
# 2024-05-09 00:28:54,804 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:54,820 - INFO - Scraping https://docs.alpaca.markets/edit/working-with-assets (depth: 3)
# 2024-05-09 00:28:55,320 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:55,336 - INFO - Scraping https://docs.alpaca.markets/edit/position-average-entry-price-calculation (depth: 3)
# 2024-05-09 00:28:55,739 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:55,755 - INFO - Scraping https://docs.alpaca.markets/edit/crypto-pricing-data (depth: 3)
# 2024-05-09 00:28:56,787 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:56,803 - INFO - Scraping https://docs.alpaca.markets/edit/stock-pricing-api (depth: 3)
# 2024-05-09 00:28:57,237 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:57,253 - INFO - Scraping https://docs.alpaca.markets/edit/market-data-faq (depth: 3)
# 2024-05-09 00:28:57,725 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:57,741 - INFO - Scraping https://docs.alpaca.markets/edit/working-with-positions (depth: 3)
# 2024-05-09 00:28:58,180 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:58,196 - INFO - Scraping https://docs.alpaca.markets/edit/fractional-trading (depth: 3)
# 2024-05-09 00:28:58,696 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:58,713 - INFO - Scraping https://docs.alpaca.markets/edit/about-market-data-api (depth: 3)
# 2024-05-09 00:28:59,163 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:59,179 - INFO - Scraping https://docs.alpaca.markets/edit/registering-your-app (depth: 3)
# 2024-05-09 00:28:59,655 - INFO - ruthless removal did not work.
# 2024-05-09 00:28:59,671 - INFO - Scraping https://docs.alpaca.markets/edit/using-oauth2-and-trading-api (depth: 3)
# 2024-05-09 00:29:00,439 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:00,455 - INFO - Scraping https://docs.alpaca.markets/edit/streaming-real-time-news (depth: 3)
# 2024-05-09 00:29:00,931 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:00,947 - INFO - Scraping https://docs.alpaca.markets/edit/statements-and-confirms (depth: 3)
# 2024-05-09 00:29:01,462 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:01,478 - INFO - Scraping https://docs.alpaca.markets/edit/working-with-orders (depth: 3)
# 2024-05-09 00:29:01,976 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:01,993 - INFO - Scraping https://docs.alpaca.markets/edit/getting-started-with-alpaca-market-data (depth: 3)
# 2024-05-09 00:29:02,421 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:02,438 - INFO - Scraping https://docs.alpaca.markets/edit/international-accounts (depth: 3)
# 2024-05-09 00:29:03,269 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:03,285 - INFO - Scraping https://docs.alpaca.markets/edit/real-time-stock-pricing-data (depth: 3)
# 2024-05-09 00:29:03,755 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:03,771 - INFO - Scraping https://docs.alpaca.markets/edit/data-validations (depth: 3)
# 2024-05-09 00:29:04,212 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:04,225 - INFO - Scraping https://docs.alpaca.markets/edit/funding-wallets (depth: 3)
# 2024-05-09 00:29:05,101 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:05,116 - INFO - Scraping https://docs.alpaca.markets/edit/real-time-option-data (depth: 3)
# 2024-05-09 00:29:05,921 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:05,937 - INFO - Scraping https://docs.alpaca.markets/edit/crypto-trading-1 (depth: 3)
# 2024-05-09 00:29:06,412 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:06,429 - INFO - Scraping https://docs.alpaca.markets/edit/domestic-usa-accounts (depth: 3)
# 2024-05-09 00:29:07,168 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:07,185 - INFO - Scraping https://docs.alpaca.markets/edit/getting-started-with-broker-api (depth: 3)
# 2024-05-09 00:29:07,622 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:07,638 - INFO - Scraping https://docs.alpaca.markets/edit/options-orders (depth: 3)
# 2024-05-09 00:29:08,321 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:08,337 - INFO - Scraping https://docs.alpaca.markets/edit/getting-started-with-trading-api (depth: 3)
# 2024-05-09 00:29:08,827 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:08,842 - INFO - Scraping https://docs.alpaca.markets/edit/real-time-crypto-pricing-data (depth: 3)
# 2024-05-09 00:29:09,353 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:09,369 - INFO - Scraping https://docs.alpaca.markets/edit/crypto-orders (depth: 3)
# 2024-05-09 00:29:09,786 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:09,801 - INFO - Scraping https://docs.alpaca.markets/login?redirect_uri=/docs/getting-started (depth: 2)
# 2024-05-09 00:29:10,561 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:10,570 - INFO - Scraping https://docs.alpaca.markets/login?redirect_uri=/ (depth: 1)
# 2024-05-09 00:29:11,204 - INFO - ruthless removal did not work.
# 2024-05-09 00:29:11,213 - INFO - Scraping complete.
